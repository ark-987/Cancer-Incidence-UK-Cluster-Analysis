# %%
import sys
from pathlib import Path

# Add project root to sys.path
sys.path.append(str(Path.cwd().parent / "src"))


from data.load_data import load_raw_data
df = load_raw_data()
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 8
#       4 # Add project root to sys.path
#       5 sys.path.append(str(Path.cwd().parent / "src"))
# ----> 8 from data.load_data import load_raw_data
#       9 df = load_raw_data()
#      10 print(df.head())
#
# ImportError: cannot import name 'load_raw_data' from 'data.load_data' (C:\Users\arkha\cancer_stats_project\src\data\load_data.py)

# %%
import data.load_data as ld
print(dir(ld))
# Out:
# ['CANCER_STATS_PROJECT', 'CONFIG_PATH', 'Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'config', 'df', 'f', 'pd', 'raw_csv_path', 'yaml']
